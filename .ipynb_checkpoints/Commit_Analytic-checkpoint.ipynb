# %% [markdown]
# # Import all the stuff

# %%
import random
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from keras import backend as K
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.optimizers import SGD
from keras.initializers import RandomUniform

from bert_serving.client import BertClient
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Testing BertClient - be sure to have the server running

# %%
bc = BertClient()
bc.encode(['First do it', 'then do it right', 'then do it better'])
# Out:
# array([[ 0.13186474,  0.32404128, -0.82704437, ..., -0.3711958 ,
#         -0.39250174, -0.31721866],
#        [ 0.24873531, -0.12334424, -0.38933852, ..., -0.44756213,
#         -0.5591355 , -0.11345179],
#        [ 0.28627345, -0.18580122, -0.30906814, ..., -0.2959366 ,
#         -0.39310536,  0.07640187]], dtype=float32)

# %% [markdown]
# # Testing Keras

# %%
x_input = np.array([[1,2,3,4,5]])
y_input = np.array([[10]])

model = Sequential()
model.add(Dense(units=32, activation="tanh", input_dim=x_input.shape[1], kernel_initializer='random_normal'))
model.add(Dense(units=1, kernel_initializer='random_normal'))

model.compile(loss='mse', optimizer='sgd', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From /Users/justinbrulotte/.pyenv/versions/3.7.3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Load the commit data

# %%
f = open("data/rubygems-raw-commits.txt", "r")
# Skip the first line
for i in range(4):
    f.readline()

# This is the first commit
commit_message = f.readline()[4:] # Removing the tab on all the commit
print("Commit:", commit_message)

commits_list = [commit_message]

# Build the other commit list
number_of_commit = 100
for i in range(number_of_commit):
    line = f.readline()
    while "commit" not in line: 
        line = f.readline()

    for i in range(3):
        f.readline()

    # This is the first commit
    commit_message = f.readline()[4:]
    
    if commit_message != '' :
        print("Commit:", commit_message)
        commits_list.append(commit_message)
        
print(commits_list)
# Out:
# Commit: Pass `--debug` flag with JRUBY_OPTS
#
# Commit: Set TRUFFLERUBYOPT only when needed
#
# Commit: Skip test that fails on jruby in debug mode
#
# Commit: Fix `gem outdated` incorrectly handling platform specific gems
#
# Commit: causing this bug.
#
# Commit: Remove weird comment
#
# Commit: Remove unnecessary method
#
# Commit: These are not needed
#
# Commit: Reduce the number of CI jobs
#
# Commit:
# Commit: Support pointing git sources to repos with default branches not named master
#
# Commit: Make tests independent from the major version
#
# Commit: Remove legacy stuff from a long time ago
#
# Commit: it 6cb7a7c03aa6131f99e52e2be4d4b22a06e0faee
#
# Commit: Apply hack to ruby 2.3 as well
#
# Commit: Test truffleruby 20.3
#
# Commit: Bump tested rubygems to latest patch levels
#
# Commit: Fix performance regression in resolver
#
# Commit: Remove unnecessary interpolation
#
# Commit:
# Commit:
# Commit: Add ruby 3.0.0 and rubygems 3.2.4 to CI
#
# Commit: Quote ruby version names in YAML files
#
# Commit: Add a missing space
#
# Commit: Bump minitest dependency to 5.14.3
#
# Commit: Always bundle dev gems using HEAD bundler
#
# Commit: Make sure `universal.x86_64` cpus are detected as x86_64
#
# Commit: Infer local platform from `RUBY_PLATFORM`
#
# Commit: Only reset platform when needed, not for every test
#
# Commit: Don't leave side effects on `Gem.platforms`
#
# Commit: Prefer setting platforms to an empty array
#
# Commit: Always set arch temporarily without side effects
#
# Commit: Restore the previous value if `util_set_arch` is passed a block
#
# Commit: Remove unused platform and return value
#
# Commit: Check things
#
# Commit:
# Commit: Setup `TargetRubyVersion` in the generated rubocop config
#
# Commit: Bump `required_ruby_version` to 2.4.0 unless user is still on 2.3
#
# Commit: Let latest rubocop be installed when it supports the running ruby
#
# Commit: Use proper rubocop requirement in Gemfile
#
# Commit: Restore support for old git
#
# Commit:
# Commit: Small refactor in git command error building
#
# Commit: Remove unnecessary "a"
#
# Commit: Tweak retry command description
#
# Commit: Show output when git command fails
#
# Commit: Simplify errors on git proxy
#
# Commit: Changelog for Rubygems version 3.2.4
#
# Commit: Changelog for Bundler version 2.2.4
#
# Commit: Maybe this will do the trick
#
# Commit:
# Commit: Fix specs
#
# Commit: Refactor
#
# Commit: Avoid some debugging crashes
#
# Commit: Update both tools in sync for ruby-core tests
#
# Commit: Better solution to `disable_multisource` migration
#
# Commit: Remove unnecessary condition
#
# Commit: Be explicit about source to improve readability
#
# Commit: Remove unneded code
#
# Commit: Consistently use `install_gemfile`
#
# Commit: Consistently use "< 3" over "= 2"
#
# Commit: Remove duplicated spec
#
# Commit: Add missing part of comment copied from other spec
#
# Commit: Consistently use `err` to check for errors
#
# Commit: Remove unneded condition
#
# Commit: Normalize spec description
#
# Commit:
# Commit:
# Commit:
# Commit:
# Commit: Stop linking to outdated page in release blog post
#
# Commit:
# Commit: Bump Rubygems version to 3.2.4
#
# Commit: Changelog for Rubygems version 3.2.4
#
# Commit: Bump Bundler version to 2.2.4
#
# Commit: Changelog for Bundler version 2.2.4
#
# Commit: Merge pull request #4213 from rubygems/fix_index_fallback
#
# Commit: or: David Rodríguez <deivid.rodriguez@riseup.net>
#
# Commit: Fixup rubocop
#
# Commit: Ignore bundler/spec/support/indexes.rb for Performance/RegexpMatch
#
# Commit: Upgrade Ruby 2.4 for the minimum version of template
#
# Commit: Revert Performance/RegexpMatch changes in own =~ methods usage.
#
# Commit: Enabled Performance/RegexpMatch cop in rubygems
#
# Commit: cd bundler && bin/rubocop -a --ignore_parent_exclusion
#
# Commit: Bump version to Ruby 2.4 on rubocop target version
#
# Commit: Drop to Ruby 2.3 and RubyGems 2.5
#
# Commit: Fix broken `bundler` executable after `gem update --system`
#
# Commit: Give a proper error if cache path does not have write access
#
# Commit: Make sure `bundle install --help` works on truffleruby
#
# Commit: Fix running `rake release` from an ambiguous ref
#
# Commit: Remove unnecessary early return
#
# Commit: Revert "Move man pages to `lib/bundler/man`"
#
# Commit: :   Wed Dec 30 12:04:50 2020 +0100
#
# Commit: Fix `gem install` resolving from the old index sometimes crashing
#
# Commit: Fix fallback to the full index not happening if source has credentials
#
# Commit: Remove unnecessary constant
#
# Commit: I don't think this method was ever used
#
# Commit: Remove stuff no longer used
#
# Commit: Merge pull request #4209 from rubygems/fix_bundle_man_pages_display_on_truffleruby
#
# Commit: :   Tue Dec 29 13:55:05 2020 +0100
#
# Commit: :   Mon Dec 28 15:52:02 2020 +0100
#
# ['Pass `--debug` flag with JRUBY_OPTS\n', 'Set TRUFFLERUBYOPT only when needed\n', 'Skip test that fails on jruby in debug mode\n', 'Fix `gem outdated` incorrectly handling platform specific gems\n', 'causing this bug.\n', 'Remove weird comment\n', 'Remove unnecessary method\n', 'These are not needed\n', 'Reduce the number of CI jobs\n', 'Support pointing git sources to repos with default branches not named master\n', 'Make tests independent from the major version\n', 'Remove legacy stuff from a long time ago\n', 'it 6cb7a7c03aa6131f99e52e2be4d4b22a06e0faee\n', 'Apply hack to ruby 2.3 as well\n', 'Test truffleruby 20.3\n', 'Bump tested rubygems to latest patch levels\n', 'Fix performance regression in resolver\n', 'Remove unnecessary interpolation\n', 'Add ruby 3.0.0 and rubygems 3.2.4 to CI\n', 'Quote ruby version names in YAML files\n', 'Add a missing space\n', 'Bump minitest dependency to 5.14.3\n', 'Always bundle dev gems using HEAD bundler\n', 'Make sure `universal.x86_64` cpus are detected as x86_64\n', 'Infer local platform from `RUBY_PLATFORM`\n', 'Only reset platform when needed, not for every test\n', "Don't leave side effects on `Gem.platforms`\n", 'Prefer setting platforms to an empty array\n', 'Always set arch temporarily without side effects\n', 'Restore the previous value if `util_set_arch` is passed a block\n', 'Remove unused platform and return value\n', 'Check things\n', 'Setup `TargetRubyVersion` in the generated rubocop config\n', 'Bump `required_ruby_version` to 2.4.0 unless user is still on 2.3\n', 'Let latest rubocop be installed when it supports the running ruby\n', 'Use proper rubocop requirement in Gemfile\n', 'Restore support for old git\n', 'Small refactor in git command error building\n', 'Remove unnecessary "a"\n', 'Tweak retry command description\n', 'Show output when git command fails\n', 'Simplify errors on git proxy\n', 'Changelog for Rubygems version 3.2.4\n', 'Changelog for Bundler version 2.2.4\n', 'Maybe this will do the trick\n', 'Fix specs\n', 'Refactor\n', 'Avoid some debugging crashes\n', 'Update both tools in sync for ruby-core tests\n', 'Better solution to `disable_multisource` migration\n', 'Remove unnecessary condition\n', 'Be explicit about source to improve readability\n', 'Remove unneded code\n', 'Consistently use `install_gemfile`\n', 'Consistently use "< 3" over "= 2"\n', 'Remove duplicated spec\n', 'Add missing part of comment copied from other spec\n', 'Consistently use `err` to check for errors\n', 'Remove unneded condition\n', 'Normalize spec description\n', 'Stop linking to outdated page in release blog post\n', 'Bump Rubygems version to 3.2.4\n', 'Changelog for Rubygems version 3.2.4\n', 'Bump Bundler version to 2.2.4\n', 'Changelog for Bundler version 2.2.4\n', 'Merge pull request #4213 from rubygems/fix_index_fallback\n', 'or: David Rodríguez <deivid.rodriguez@riseup.net>\n', 'Fixup rubocop\n', 'Ignore bundler/spec/support/indexes.rb for Performance/RegexpMatch\n', 'Upgrade Ruby 2.4 for the minimum version of template\n', 'Revert Performance/RegexpMatch changes in own =~ methods usage.\n', 'Enabled Performance/RegexpMatch cop in rubygems\n', 'cd bundler && bin/rubocop -a --ignore_parent_exclusion\n', 'Bump version to Ruby 2.4 on rubocop target version\n', 'Drop to Ruby 2.3 and RubyGems 2.5\n', 'Fix broken `bundler` executable after `gem update --system`\n', 'Give a proper error if cache path does not have write access\n', 'Make sure `bundle install --help` works on truffleruby\n', 'Fix running `rake release` from an ambiguous ref\n', 'Remove unnecessary early return\n', 'Revert "Move man pages to `lib/bundler/man`"\n', ':   Wed Dec 30 12:04:50 2020 +0100\n', 'Fix `gem install` resolving from the old index sometimes crashing\n', 'Fix fallback to the full index not happening if source has credentials\n', 'Remove unnecessary constant\n', "I don't think this method was ever used\n", 'Remove stuff no longer used\n', 'Merge pull request #4209 from rubygems/fix_bundle_man_pag ...

# %% [markdown]
# # Run the main modal

# %%
bert_encode_commits = bc.encode(commits_list)
